# %%
import pandas as pd

# %%
df_iris = pd.read_csv("iris.data.txt", header=None, usecols=[0, 1, 2, 3])

# %%
df_iris
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
import skcriteria as skc
from skcriteria.preprocessing.scalers import VectorScaler, SumScaler
from skcriteria.agg.topsis import TOPSIS
from skcriteria.agg.electre import ELECTRE2
from skcriteria.ranksrev.rank_transitivity_check import RankTransitivityChecker

# %%
# def test_TOPSIS_tzeng2011multiple():
#     """
#     Data from:
#         Tzeng, G. H., & Huang, J. J. (2011).
#         Multiple attribute decision making: methods and applications.
#         CRC press.

#     """
#     dm = skcriteria.mkdm(
#         matrix=[
#             [5, 8, 4],
#             [7, 6, 8],
#             [8, 8, 6],
#             [7, 4, 6],
#         ],
#         objectives=[max, max, max],
#         weights=[0.3, 0.4, 0.3],
#     )

#     transformer = VectorScaler(target="matrix")
#     dm = transformer.transform(dm)

#     expected = RankResult(
#         "TOPSIS",
#         ["A0", "A1", "A2", "A3"],
#         [3, 2, 1, 4],
#         {"similarity": [0.5037, 0.6581, 0.7482, 0.3340]},
#     )

#     ranker = TOPSIS()
#     result = ranker.evaluate(dm)

#     assert result.values_equals(expected)
#     assert result.method == expected.method
#     assert np.allclose(
#         result.e_.similarity, expected.e_.similarity, atol=1.0e-4
#     )


dm_TOPSIS_tzeng2011multiple = skc.mkdm(
        matrix=[
            [5, 8, 4],
            [7, 6, 8],
            [8, 8, 6],
            [7, 4, 6],
        ],
        objectives=[max, max, max],
        weights=[0.3, 0.4, 0.3],
    )

transformer = VectorScaler(target="matrix")

pipeline_TOPSIS_tzeng2011multiple = skc.pipeline.mkpipe(transformer, TOPSIS())

pipeline_TOPSIS_tzeng2011multiple.evaluate(dm_TOPSIS_tzeng2011multiple)
# Out:
# /home/divasco/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/pipeline.py:27: SKCriteriaDeprecationWarning: The 'skcriteria.pipeline' module is deprecated since 0.9 and will be removed in 1.0 Use 'skcriteria.pipelines' instead.
#   deprecate.warn(
# Alternatives  A0  A1  A2  A3
# Rank           3   2   1   4
# [Method: TOPSIS]

# %%
# def test_ELECTRE2_cebrian2009localizacion():
#     """
#     Data From:
#         Cebrián, L. I. G., & Porcar, A. M. (2009). Localización empresarial
#         en Aragón: Una aplicación empírica de la ayuda a la decisión
#         multicriterio tipo ELECTRE I y III. Robustez de los resultados
#         obtenidos.
#         Revista de Métodos Cuantitativos para la Economía y la Empresa,
#         (7), 31-56.

#     """
#     dm = skcriteria.mkdm(
#         matrix=[
#             [6, 5, 28, 5, 5],
#             [4, 2, 25, 10, 9],
#             [5, 7, 35, 9, 6],
#             [6, 1, 27, 6, 7],
#             [6, 8, 30, 7, 9],
#             [5, 6, 26, 4, 8],
#         ],
#         objectives=[1, 1, -1, 1, 1],
#         weights=[0.25, 0.25, 0.1, 0.2, 0.2],
#     )

#     scaler = SumScaler("both")
#     dm = scaler.transform(dm)

#     kselector = ELECTRE2()
#     result = kselector.evaluate(dm)

#     assert np.all(result.rank_ == [6, 3, 2, 5, 1, 4])
#     np.testing.assert_allclose(result.e_.score, [5.0, 2.5, 2.0, 4.0, 1.0, 3.0])

dm_ELECTRE2_cebrian2009localizacion = skc.mkdm(
    matrix=[
        [6, 5, 28, 5, 5],
        [4, 2, 25, 10, 9],
        [5, 7, 35, 9, 6],
        [6, 1, 27, 6, 7],
        [6, 8, 30, 7, 9],
        [5, 6, 26, 4, 8],
    ],
    objectives=[1, 1, -1, 1, 1],
    weights=[0.25, 0.25, 0.1, 0.2, 0.2],
)

pipeline_ELECTRE2_cebrian2009localizacion = skc.pipeline.mkpipe(SumScaler("both"), ELECTRE2())

print(pipeline_ELECTRE2_cebrian2009localizacion.evaluate(dm_ELECTRE2_cebrian2009localizacion))


# def test_ELECTRE2_wang2006():
#     """
#     Data From:
#         Xiaoting Wang, Evangelos Triantaphyllou,
#             Ranking irregularities when evaluating alternatives by using
#             some ELECTRE methods,
#         Omega,
#         Volume 36, Issue 1,
#         2008,

#     """
#     dm = skcriteria.mkdm(
#         matrix=[
#             [1, 2, 1, 5, 2, 2, 4],
#             [3, 5, 3, 5, 3, 3, 3],
#             [3, 5, 3, 5, 3, 2, 2],
#             [1, 2, 2, 5, 1, 1, 1],
#             [1, 1, 3, 5, 4, 1, 5],
#         ],
#         alternatives=["A1", "A2", "A3", "A4", "A5"],
#         objectives=[max, max, max, max, max, max, max],
#         weights=[0.0780, 0.1180, 0.1570, 0.3140, 0.2350, 0.0390, 0.0590],
#     )

#     kselector = ELECTRE2()
#     result = kselector.evaluate(dm)

#     assert np.all(result.rank_ == [4, 1, 3, 5, 2])
#     np.testing.assert_allclose(result.e_.score, [3.0, 1.0, 2.0, 4.0, 1.5])

dm_ELECTRE2_wang2006 = skc.mkdm(
    matrix=[
        [1, 2, 1, 5, 2, 2, 4],
        [3, 5, 3, 5, 3, 3, 3],
        [3, 5, 3, 5, 3, 2, 2],
        [1, 2, 2, 5, 1, 1, 1],
        [1, 1, 3, 5, 4, 1, 5],
    ],
    alternatives=["A1", "A2", "A3", "A4", "A5"],
    objectives=[max, max, max, max, max, max, max],
    weights=[0.0780, 0.1180, 0.1570, 0.3140, 0.2350, 0.0390, 0.0590],
)

pipeline_ELECTRE2_wang2006 = ELECTRE2()

print(pipeline_ELECTRE2_wang2006.evaluate(dm_ELECTRE2_wang2006))
# Out:
# Alternatives  A0  A1  A2  A3  A4  A5
# Rank           6   3   2   5   1   4
# [Method: ELECTRE2]
# Alternatives  A1  A2  A3  A4  A5
# Rank           4   1   3   5   2
# [Method: ELECTRE2]

# %%
steps = [
    [
        SumScaler("both"),
        VectorScaler(target="matrix")
    ],
    [
        ELECTRE2(),
        TOPSIS()
    ]
]
combined_pipelines = skc.pipelines.mkcombinatorial(*steps)

# %%
combined_pipelines.named_pipelines
# Out:
# <pipelines {'VectorScaler_ELECTRE2', 'SumScaler_TOPSIS', 'VectorScaler_TOPSIS', 'SumScaler_ELECTRE2'}>

# %%
dm_iris = skc.mkdm(df_iris.to_numpy(), objectives=[1, 1, 1, 1])

# %%
dm_iris
# Out:
# /home/divasco/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/pandas/io/formats/format.py:1354: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   for val, m in zip(values.ravel(), mask.ravel())
# /home/divasco/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/pandas/io/formats/format.py:1354: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   for val, m in zip(values.ravel(), mask.ravel())
#       C0[▲ 1.0]  C1[▲ 1.0]  C2[▲ 1.0]  C3[▲ 1.0]
# A0          5.1        3.5        1.4        0.2
# A1          4.9        3.0        1.4        0.2
# A2          4.7        3.2        1.3        0.2
# A3          4.6        3.1        1.5        0.2
# A4          5.0        3.6        1.4        0.2
# ...         ...        ...        ...        ...
# A145        6.7        3.0        5.2        2.3
# A146        6.3        2.5        5.0        1.9
# A147        6.5        3.0        5.2        2.0
# A148        6.2        3.4        5.4        2.3
# A149        5.9        3.0        5.1        1.8
# [150 Alternatives x 4 Criteria]

# %%
res = combined_pipelines.evaluate(dm_iris)

rrc = skc.ranksrev.RankTransitivityChecker(combined_pipelines)

# %%
rComps = []

for pipeline in combined_pipelines.pipelines[1:]:
    print(pipeline[1])
    print("------------")
    print(skc.pipeline.mkpipe(*pipeline[1]))
    rrc = skc.ranksrev.RankTransitivityChecker(pipeline[1])
    rev_test = rrc.evaluate(dm=dm_iris)
    rcomps.append(rev_test)

# rrc = skc.ranksrev.RankTransitivityChecker(combined_pipelines)
# Out:
# <SKCPipeline [steps=[('sumscaler_vectorscaler', <SumScaler [target='both']>), ('electre2_topsis', <TOPSIS [metric='euclidean']>)]]>
# ------------
# <SKCPipeline [steps=[('sumscaler', <SumScaler [target='both']>), ('topsis', <TOPSIS [metric='euclidean']>)]]>
# /home/divasco/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/agg/topsis.py:62: RuntimeWarning: invalid value encountered in divide
#   similarity = d_worst / (d_better + d_worst)
# /home/divasco/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/utils/rank.py:67: RuntimeWarning: invalid value encountered in cast
#   return stats.rankdata(arr, "dense").astype(np.int64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 8
#       6 print(skc.pipeline.mkpipe(*pipeline[1]))
#       7 rrc = skc.ranksrev.RankTransitivityChecker(pipeline[1])
# ----> 8 rev_test = rrc.evaluate(dm=dm_iris)
#       9 rcomps.append(rev_test)
#      10 print(rcomps[-1])
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/ranksrev/rank_transitivity_check.py:1090, in RankTransitivityChecker.evaluate(self, dm)
#    1080 patched_rrank = self._add_break_info_to_rank(
#    1081     rrank,
#    1082     dag=None,
#    (...)   1085     iteration=None,
#    1086 )
#    1088 # make the pairwise dominance graph and calculate transitivity metrics
#    1089 test_criterion_2, graph, trans_break, trans_break_rate = (
# -> 1090     self._test_criterion_2(
#    1091         dm,
#    1092         rrank,
#    1093         preferred_parallel_backend=preferred_parallel_backend,
#    1094         n_jobs=n_jobs,
#    1095     )
#    1096 )
#    1098 # get the ranks from the graph
#    1099 reconstructed_ranks = self._generate_reconstructed_ranks(
#    1100     graph, rrank, full_alternatives
#    1101 )
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/ranksrev/rank_transitivity_check.py:1009, in RankTransitivityChecker._test_criterion_2(self, dm, orank, preferred_parallel_backend, n_jobs)
#     967 """
#     968 Perform test criterion 2: transitivity consistency check.
#     969
#    (...)   1006 and B dominates C, then A must also dominate C.
#    1007 """
#    1008 # make the pairwise dominance graph and calculate transitivity metrics
# -> 1009 graph, trans_break, trans_break_rate = self._generate_graph_data(
#    1010     dm, orank, preferred_parallel_backend, n_jobs
#    1011 )
#    1013 test_criterion_2 = trans_break_rate == 0
#    1014 return test_criterion_2, graph, trans_break, trans_break_rate
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/ranksrev/rank_transitivity_check.py:955, in RankTransitivityChecker._generate_graph_data(self, dm, rrank, preferred_parallel_backend, n_jobs)
#     924 """
#     925 Generate dominance graph and calculate transitivity metrics.
#     926
#    (...)    952     (0.0 = perfect transitivity).
#     953 """
#     954 # Create pairwise dominance graph
# --> 955 graph = self._dominance_graph(
#     956     dm, rrank, preferred_parallel_backend, n_jobs
#     957 )
#     959 # Calculate transitivity break, and it's rate
#     960 trans_break, trans_break_rate = self._calculate_transitivity_break(
#     961     graph
#     962 )
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/ranksrev/rank_transitivity_check.py:875, in RankTransitivityChecker._dominance_graph(self, dm, rrank, preferred_parallel_backend, n_jobs)
#     869 with joblib.Parallel(
#     870     prefer=preferred_parallel_backend, n_jobs=n_jobs
#     871 ) as P:
#     872     delayed_evaluation = joblib.delayed(
#     873         self._evaluate_pairwise_submatrix
#     874     )
# --> 875     results = P(
#     876         delayed_evaluation(dm, pair) for pair in pairwise_combinations
#     877     )
#     879 edges = self._get_graph_edges(results, dm)
#     881 # Create directed graph
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/ranksrev/rank_transitivity_check.py:586, in RankTransitivityChecker._evaluate_pairwise_submatrix(self, decision_matrix, alternative_pair)
#     553 """
#     554 Apply the MCDM pipeline to a sub-problem of two alternatives.
#     555
#    (...)    583 problem is decomposed into smaller two-alternative subproblems.
#     584 """
#     585 sub_dm = decision_matrix.loc[alternative_pair]
# --> 586 return self._pair_evaluator.evaluate(sub_dm)
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/pipelines/simple_pipeline.py:144, in SKCPipeline.evaluate(self, dm)
#     142 dm = self.transform(dm)
#     143 _, dmaker = self.steps[-1]
# --> 144 result = dmaker.evaluate(dm)
#     145 return result
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/agg/_agg_base.py:225, in SKCDecisionMakerABC.evaluate(self, dm)
#     211 def evaluate(self, dm):
#     212     """Validate the dm and calculate and evaluate the alternatives.
#     213
#     214     Parameters
#    (...)    223
#     224     """
# --> 225     return self._evaluate_dm(dm)
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/agg/_agg_base.py:203, in SKCDecisionMakerABC._evaluate_dm(self, dm, **kwargs)
#     200 result_data, extra = self._evaluate_data(**data, **kwargs)
#     202 alternatives = data["alternatives"]
# --> 203 result = self._make_result(
#     204     alternatives=alternatives,
#     205     values=result_data,
#     206     extra=extra,
#     207 )
#     209 return result
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/agg/topsis.py:147, in TOPSIS._make_result(self, alternatives, values, extra)
#     145 @doc_inherit(SKCDecisionMakerABC._make_result)
#     146 def _make_result(self, alternatives, values, extra):
# --> 147     return RankResult(
#     148         "TOPSIS", alternatives=alternatives, values=values, extra=extra
#     149     )
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/agg/_agg_base.py:263, in ResultABC.__init__(self, method, alternatives, values, extra)
#     262 def __init__(self, method, alternatives, values, extra):
# --> 263     self._validate_result(values)
#     264     self._method = str(method)
#     265     self._extra = Bunch("extra", extra)
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/agg/_agg_base.py:429, in RankResult._validate_result(self, values)
#     426 @doc_inherit(ResultABC._validate_result)
#     427 def _validate_result(self, values):
#     428     if not rank.is_rank(values):
# --> 429         raise ValueError(f"The data {values} doesn't look like a ranking")
#
# ValueError: The data [-9223372036854775808 -9223372036854775808] doesn't look like a ranking

# %%
# rrc.evaluate(dm=dm_iris)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 rrc.evaluate(dm=dm_iris)
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/ranksrev/rank_transitivity_check.py:1080, in RankTransitivityChecker.evaluate(self, dm)
#    1078 # we need a first reference ranking
#    1079 rrank = dmaker.evaluate(dm)
# -> 1080 patched_rrank = self._add_break_info_to_rank(
#    1081     rrank,
#    1082     dag=None,
#    1083     removed_edges=None,
#    1084     full_alternatives=full_alternatives,
#    1085     iteration=None,
#    1086 )
#    1088 # make the pairwise dominance graph and calculate transitivity metrics
#    1089 test_criterion_2, graph, trans_break, trans_break_rate = (
#    1090     self._test_criterion_2(
#    1091         dm,
#    (...)   1095     )
#    1096 )
#
# File ~/Documents/RankReversalTesting/.venv/lib/python3.13/site-packages/skcriteria/ranksrev/rank_transitivity_check.py:675, in RankTransitivityChecker._add_break_info_to_rank(self, rank, dag, removed_edges, full_alternatives, iteration)
#     635 def _add_break_info_to_rank(
#     636     self, rank, dag, removed_edges, full_alternatives, iteration
#     637 ):
#     638     """
#     639     Add cycle-breaking information to a ranking result.
#     640
#    (...)    673             - removed_edges: edges removed during cycle breaking
#     674     """
# --> 675     alternatives = rank.alternatives
#     676     values = rank.values
#     677     method = rank.method
#
# AttributeError: 'RanksComparator' object has no attribute 'alternatives'
